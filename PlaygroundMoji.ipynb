# %%
#@title 1. Preparar o Ambiente (Execute apenas uma vez) / Prepare the Environment (Run only once)
print("🐻 Cloning the Moji repository...")
# !git clone https://github.com/ArtFaz/Moji
# %cd Moji

print("\n🐍 Installing dependencies...")
# !pip install -r requirements.txt

print("\n✅ Environment ready! You can scroll to the next block.")

# %%
#@title 2. ⌨️ Playground do Moji | ⌨️ Moji's Playground
#@markdown Digite seu código Moji na caixa abaixo e aperte o play (▶️) na célula.

#@markdown Type your Moji code in the box below and press play (▶️) in the cell.


moji_code = """
🌱
💭 Este é o "Hello World!" do Moji.
💭 Sinta-se à vontade para editar!

💬 hello 👉 "Olá" 🔚
💬 world 👉 "Moji!" 🔚
🖨️ hello ➕ " " ➕ world 🔚

🔢 a 👉 10 🔚
👽 b 👉 5.5 🔚
👽 sum 👉 a ➕ b 🔚

🖨️ "Soma (10 + 5.5): " ➕ sum 🔚
🌳
"""

# Salva o código do usuário em um arquivo temporário
with open("playground.moji", "w", encoding="utf-8") as f:
    f.write(moji_code)

# Executa o interpretador main.py com o arquivo criado
print("--- Running your Moji code 🐻 ---")
# !python main.py playground.moji
print("--- End of runtime ---")

# %%
#@title 3. (Opcional) Executar Exemplos Prontos | (Optional) Run Ready-Made Examples
#@markdown Rode esta célula para ver a saída do exemplo "condicionais.moji"

#@markdown Run this cell to see the output of the "conditionals.moji" example


print("--- Running /examples/condicionais.moji ---")
# !python main.py examples/condicionais.moji
print("--- End of runtime ---")
